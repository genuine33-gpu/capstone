# %% [markdown]
# In this project, we will analyze human resources data by performing data wrangling & EDA.
#
# We will learn how to:

# %% [markdown]
# # CODING TASK #1. IMPORT DATASET AND PERFORM BASIC STATISTICAL DATA ANALYSIS

# %% [markdown]
# - **Import Pandas Library**
#
# - **Force Pandas to display all rows and columns**
#
# - **Let's read a CSV file using Pandas as follows**
#
# - **Let's obtain the datatype**
#
# - **you can view the first couple of rows using .head()**
#
# - **you can view the last couple of rows using .tail()**
#
# - **Calculate the average values for employee_df dataframe**
#
# - **35 features in total**
#
# - **Obtain a Statistical Summary about the data**

# %%
#Import Pandas Library
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
# Force Pandas to display all rows and columns
pd.set_option('display.max_columns', None)  # all columns view
pd.set_option('display.max_rows', None)  # all rows view
hr_df

# %%
#Let's obtain the datatype
hr_df.dtypes
# Out:
# Age                           int64
# MonthlyIncome               float64
# Attrition                    object
# BusinessTravel               object
# DailyRate                     int64
# Department                   object
# DistanceFromHome              int64
# Education                     int64
# EducationField               object
# EmployeeCount                 int64
# EmployeeNumber              float64
# EnvironmentSatisfaction       int64
# Gender                       object
# HourlyRate                    int64
# JobInvolvement                int64
# JobLevel                      int64
# JobRole                      object
# JobSatisfaction               int64
# MaritalStatus                object
# MonthlyRate                 float64
# NumCompaniesWorked            int64
# Over18                       object
# OverTime                     object
# PercentSalaryHike           float64
# PerformanceRating           float64
# RelationshipSatisfaction      int64
# ...

# %%
hr_df.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# 1              1             2.0                        3    Male          61
# 2              1             4.0                        4    Male          92
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# ...

# %%
#you can view the last couple of rows using .tail()
hr_df.tail(3)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  \
# 1467              1          2064.0                        2   Male
# 1468              1          2065.0                        4   Male
# 1469              1          2068.0                        2   Male
#
#       HourlyRate  JobInvolvement  JobLevel                 JobRole  \
# ...

# %%
#Calculate the average values for employee_df dataframe
hr_df.mean()
# Out:
# Age                            36.923810
# MonthlyIncome                6505.155419
# DailyRate                     802.485714
# DistanceFromHome                9.192517
# Education                       2.912925
# EmployeeCount                   1.000000
# EmployeeNumber               1025.556161
# EnvironmentSatisfaction         2.721769
# HourlyRate                     65.891156
# JobInvolvement                  2.729932
# JobLevel                        2.063946
# JobSatisfaction                 2.728571
# MonthlyRate                 14310.966621
# NumCompaniesWorked              2.693197
# PercentSalaryHike              15.206263
# PerformanceRating               3.153165
# RelationshipSatisfaction        2.712245
# StandardHours                  80.000000
# StockOptionLevel                0.793878
# TotalWorkingYears              11.279592
# TrainingTimesLastYear           2.799320
# WorkLifeBalance                 2.761224
# YearsAtCompany                  7.008163
# ...

# %%
#35 features in total
#Obtain a Statistical Summary about the data
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %%
hr_df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# MonthlyIncome             1467.0   6505.155419  4711.297846  1009.0  2911.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1469.0   1025.556161   601.646166     1.0   492.00
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# ...

# %%
hr_df.select_dtypes(include='number').hist(figsize=(15,20))
plt.show()

# %%
categorical_columns = hr_df.select_dtypes(include='object').columns

# Define a color palette
colors = sns.color_palette('Set2', len(categorical_columns))

fig, axes = plt.subplots(3, 3, figsize=(15, 12))
for i, ax in enumerate(axes.flatten()):
    col = categorical_columns[i]
    val_cnt = hr_df[col].value_counts()
    sns.barplot(x=val_cnt.index, y=val_cnt.values, ax=ax, palette=colors)
    ax.set_title(f"Frequencies of {col} feature")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90)


plt.tight_layout()
plt.show()

# %%
# lets also see some other metrics related to employee ages
# There is a subtle usage of ' and " here, lets notice this difference
# Remember to use " not ' to escape ' in the f string
# Also notice to write the code in 2 lines according to PEP rules, and printing out the results in 2 lines according to PEP rules

print(f"The average of employee age is {round(np.mean(hr_df['Age']))}"
      f"\nwhere as the minimum and maximum ages are {np.min(hr_df['Age'])} and {np.max(hr_df['Age'])} consecutively")
# Out:
# The average of employee age is 37
# where as the minimum and maximum ages are 18 and 60 consecutively

# %% [markdown]
# **PRACTICE OPPORTUNITY #1:**
# - **Calculate the mean, maximum and minimum employee age considered in this study using a different strategy**

# %%
#Calculate the mean, maximum and minimum employee age considered in this study using a different strategy
age_stats = hr_df['Age'].describe()[['mean', 'min', 'max']]
age_stats
# Out:
# mean    36.92381
# min     18.00000
# max     60.00000
# Name: Age, dtype: float64

# %% [markdown]
# # CODING TASK #2. DEALING WITH MISSING DATA

# %% [markdown]
# - **Let's locate rows that have Null values**
#
# - **Notice Row index 6 has many missing values**
#
# - **Let's see the total number of missing elements per column**
#
# - **Drop any row that contains a Null value**
#
# - **Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463**
#
# - **Notice that row 1 for example is no longer existing!**
#
# - **Let's check if we still have any missing values**
#
# - **Let's explore an alternative (smarter) method to deal with missing values**
#
# - **Let's read the raw data again using Pandas as follows**
#
# - **Calculate the average monthly income**
#
# - **You can use Fillna to fill a given column with a certain value**

# %%
hr_df = pd.read_csv('Human_Resources.csv')

# %%
#Let's locate rows that have Null values
hr_df [hr_df.isnull().any(axis =1)]
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1     49            NaN        No  Travel_Frequently        279
# 6     59            NaN        No      Travel_Rarely       1324
# 7     30         2693.0        No      Travel_Rarely       1358
# 17    22         2935.0        No         Non-Travel       1123
# 23    21         1232.0        No      Travel_Rarely        391
# 103   34         4809.0        No      Travel_Rarely        665
# 947   52            NaN       Yes      Travel_Rarely       1030
#
#                  Department  DistanceFromHome  Education EducationField  \
# 1    Research & Development                 8          1  Life Sciences
# 6    Research & Development                 3          3            NaN
# 7                       NaN                24          1  Life Sciences
# 17   Research & Development                16          2        Medical
# 23   Research & Development                15          2  Life Sciences
# ...

# %%
#Notice Row index 6 has many missing values
#Yes we paid attention

# %%
#Let's see the total number of missing elements per column
df_column = hr_df.isnull().sum()
df_column
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
nan_column_count = hr_df.isnull().any().sum()
print(f"Totally {nan_column_count} columns have missing values ")
# Out:
# Totally 10 columns have missing values

# %%
#Drop any row that contains a Null value
df = hr_df.dropna()
df

# %%
#Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1463 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1463 non-null   int64
#  1   MonthlyIncome             1463 non-null   float64
#  2   Attrition                 1463 non-null   object
#  3   BusinessTravel            1463 non-null   object
#  4   DailyRate                 1463 non-null   int64
#  5   Department                1463 non-null   object
#  6   DistanceFromHome          1463 non-null   int64
#  7   Education                 1463 non-null   int64
#  8   EducationField            1463 non-null   object
#  9   EmployeeCount             1463 non-null   int64
#  10  EmployeeNumber            1463 non-null   float64
#  11  EnvironmentSatisfaction   1463 non-null   int64
#  12  Gender                    1463 non-null   object
# ...

# %%
#Let's check if we still have any missing values
df_column = df.isnull().sum()
df_column
# Out:
# Age                         0
# MonthlyIncome               0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Let's explore an alternative (smarter) method to deal with missing values
#Let's read the raw data again using Pandas as follows

# %%
#Calculate the average monthly income
monthly_mean = df['MonthlyIncome'].mean()
monthly_mean
# Out:
# 6514.965140123035

# %%
#You can use Fillna to fill a given column with a certain value
hr_df['MonthlyIncome'].fillna(monthly_mean, inplace = True)
hr_df

# %% [markdown]
# **PRACTICE OPPORTUNITY #2:**
# - **Calculate the median monthly rate. Use the calculated median values to fill out missing data. Confirm that the process is successful**

# %%
median_rate = hr_df['MonthlyRate'].median()
median_rate
# Out:
# 14235.5

# %%
hr_df['MonthlyRate'].fillna(median_rate, inplace = True)
hr_df

# %% [markdown]
# # CODING TASK #3: PERFORM ONE-HOT ENCODING [OPTIONAL]

# %% [markdown]
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df

# %%
hr_df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
hr_df['BusinessTravel']

# %%
BusinessTravel_Encoded = pd.get_dummies(hr_df['BusinessTravel'])
print(BusinessTravel_Encoded)

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %%
#Import the Human Resources data and remove all missing values
hr_df = hr_df.dropna()
hr_df = hr_df.reset_index(drop=True)
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   37         2090.0       Yes      Travel_Rarely       1373
# 2   33         2909.0        No  Travel_Frequently       1392
# 3   27         3468.0        No      Travel_Rarely        591
# 4   32         3068.0        No  Travel_Frequently       1005
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 2          2          Other
# 2  Research & Development                 3          4  Life Sciences
# 3  Research & Development                 2          1        Medical
# 4  Research & Development                 2          2  Life Sciences
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# ...

# %%
#How many unique categories exist in the Education Field column?
hr_df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
hr_df['EducationField'].head()
# Out:
# 0    Life Sciences
# 1            Other
# 2    Life Sciences
# 3          Medical
# 4    Life Sciences
# Name: EducationField, dtype: object

# %%
#Perform one hot encoding to the Education Field column
BusinessTravel_Encoded = pd.get_dummies(hr_df['EducationField'])
print(BusinessTravel_Encoded)

# %% [markdown]
# # CODING TASK #4: PERFORM SCALING (NORMALIZATION & STANDARDIZATION) [OPTIONAL]

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df

# %%
hr_df['Age'].values
# Out:
# array([41, 49, 37, ..., 27, 49, 34], dtype=int64)

# %%
# Normalization is conducted to make feature values range from 0 to 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
hr_df['Age'] = scaler.fit_transform(hr_df['Age'].values.reshape(-1,1))

# %%
hr_df['Age']

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Perform feature scaling by performing standardization (Recall that Standardization is conducted to transform the data to have a mean of zero and standard deviation of 1.**
# - **Perform a sanity check to ensure that the transformation was successful**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Standardization (z-score scaling)
scaler_standardization = StandardScaler()
hr_df["HourlyRate_Standardized"] = scaler_standardization.fit_transform(hr_df[["HourlyRate"]])

# Normalization (min-max scaling)
scaler_normalization = MinMaxScaler()
hr_df["HourlyRate_Normalized"] = scaler_normalization.fit_transform(hr_df[["HourlyRate"]])

# Sanity check: Print the scaled columns
print("Scaled Data (Standardization):\n", hr_df["HourlyRate_Standardized"])

# %%
print("\nScaled Data (Normalization):\n", hr_df["HourlyRate_Normalized"])

# %%
hr_df

# %% [markdown]
# # CODING TASK #5. PANDAS OPERATIONS/FILTERING

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')

# %% [markdown]
# - **Pick certain rows that satisfy a certain criteria**
#
# - **Pick certain rows that satisfy 2 or more critirea**
#
# - **values that fall between a given range**

# %%
#Pick certain rows that satisfy a certain criteria
flt_hr_df = hr_df[hr_df['Age'] < 19]
flt_hr_df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 296    18         1420.0       Yes      Travel_Rarely        230
# 301    18         1200.0        No      Travel_Rarely        812
# 457    18         1878.0       Yes  Travel_Frequently       1306
# 727    18         1051.0        No         Non-Travel        287
# 828    18         1904.0       Yes         Non-Travel        247
# 972    18         1611.0        No         Non-Travel       1124
# 1153   18         1569.0       Yes  Travel_Frequently        544
# 1311   18         1514.0        No         Non-Travel       1431
#
#                   Department  DistanceFromHome  Education EducationField  \
# 296   Research & Development                 3          3  Life Sciences
# 301                    Sales                10          3        Medical
# 457                    Sales                 5          3      Marketing
# 727   Research & Development                 5          2  Life Sciences
# ...

# %%
# Pick certain rows that satisfy 2 or more critirea
flt_hr_df1 = hr_df[(hr_df['Age'] < 19) & (hr_df['Department'] == "Sales") ]
flt_hr_df1
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate Department  \
# 301    18         1200.0        No      Travel_Rarely        812      Sales
# 457    18         1878.0       Yes  Travel_Frequently       1306      Sales
# 1153   18         1569.0       Yes  Travel_Frequently        544      Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 301                 10          3        Medical              1
# 457                  5          3      Marketing              1
# 1153                 3          2        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 301            411.0                        4  Female          69
# 457            614.0                        2    Male          69
# 1153          1624.0                        2  Female          70
#
#       JobInvolvement  JobLevel               JobRole  JobSatisfaction  \
# ...

# %%
#values that fall between a given range
flt_hr_df2 = hr_df[(hr_df['Age'] >38) & (hr_df['Age'] <= 41) ]
len(flt_hr_df2)
# Out:
# 139

# %% [markdown]
# **PRACTICE OPPORTUNITY #5:**
# - **Using "hr_df" DataFrame, leverage pandas operations to only select high DailyRate individuals (1450+)**
# - **What is the combined Daily Rate for all employees with 1450+?**

# %%
#Using "hr_df" DataFrame, leverage pandas operations to only select high DailyRate individuals (1450+)
flt_hr_df3 = hr_df[(hr_df['DailyRate'] > 1450)]
flt_hr_df3

# %%
#What is the combined Daily Rate for all employees with 1450+?
flt_hr_df3["DailyRate"].sum()
# Out:
# 70849

# %% [markdown]
# # CODING TASK #6: PERFORM BASIC EDA ON BOTH CLASSES

# %% [markdown]
# - **It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other**
# - **Let's see how many employees left the company! Let's drop 'EmployeeNumber' as well**
# - **Let's see how many employees left the company!**
# - **View employees who left**

# %%
hr_df["EmployeeCount"].nunique()
# Out:
# 1

# %%
hr_df["StandardHours"].nunique()
# Out:
# 1

# %%
hr_df["Over18"].nunique()
# Out:
# 1

# %%
#It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other
hr_df = hr_df.drop(["EmployeeCount","StandardHours", "Over18"], axis=1)
hr_df

# %%
#Let's see how many employees left the company! Let's drop 'EmployeeNumber' as well
attrition_count = hr_df[hr_df["Attrition"] == "Yes"]["Attrition"].count()
attrition_count
# Out:
# 237

# %%
hr_df = hr_df.drop("EmployeeNumber", axis=1)
hr_df

# %%
#Let's see how many employees left the company!
attrition_count = hr_df[hr_df["Attrition"] == "Yes"]["Attrition"].count()
attrition_count
# Out:
# 237

# %%
#View employees who left
people_left= hr_df[hr_df["Attrition"] == "Yes"]
people_left

# %% [markdown]
# **PRACTICE OPPORTUNITY #6:**
# - **Filter the hr_df to only include the employees who stayed in the company**
# - **Generate statistical summary for employees who stayed**
# - **Compare both statistical summaries. What do you infer from the data?**

# %%
#Filter the hr_df to only include the employees who stayed in the company
employees_who_stayed = hr_df[hr_df["Attrition"] == "No"]
employees_who_stayed.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1   49            NaN        No  Travel_Frequently        279
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
# 5   32         3068.0        No  Travel_Frequently       1005
# 6   59            NaN        No      Travel_Rarely       1324
#
#                Department  DistanceFromHome  Education EducationField  \
# 1  Research & Development                 8          1  Life Sciences
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
# 5  Research & Development                 2          2  Life Sciences
# 6  Research & Development                 3          3            NaN
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 1                        3    Male          61               2         2
# ...

# %%
#Generate statistical summary for employees who stayed
employees_who_stayed.describe().T
# Out:
#                            count          mean          std     min     25%  \
# Age                       1233.0     37.561233     8.888360    18.0    31.0
# MonthlyIncome             1231.0   6837.504468  4820.415800  1051.0  3211.5
# DailyRate                 1233.0    812.504461   403.208379   102.0   477.0
# DistanceFromHome          1233.0      8.915653     8.012633     1.0     2.0
# Education                 1233.0      2.927007     1.027002     1.0     2.0
# EnvironmentSatisfaction   1233.0      2.771290     1.071132     1.0     2.0
# HourlyRate                1233.0     65.952149    20.380754    30.0    48.0
# JobInvolvement            1233.0      2.770479     0.692050     1.0     2.0
# JobLevel                  1233.0      2.145985     1.117933     1.0     1.0
# JobSatisfaction           1233.0      2.778589     1.093277     1.0     2.0
# MonthlyRate               1231.0  14263.154346  7106.411508  2094.0  7961.5
# ...

# %%
people_left.describe().T
# Out:
#                           count          mean          std     min     25%  \
# Age                       237.0     33.607595     9.689350    18.0    28.0
# MonthlyIncome             236.0   4771.588983  3640.097444  1009.0  2371.5
# DailyRate                 237.0    750.362869   401.899519   103.0   408.0
# DistanceFromHome          237.0     10.632911     8.452525     1.0     3.0
# Education                 237.0      2.839662     1.008244     1.0     2.0
# EnvironmentSatisfaction   237.0      2.464135     1.169791     1.0     1.0
# HourlyRate                237.0     65.573840    20.099958    31.0    50.0
# JobInvolvement            237.0      2.518987     0.773405     1.0     2.0
# JobLevel                  237.0      1.637131     0.940594     1.0     1.0
# JobSatisfaction           237.0      2.468354     1.118058     1.0     1.0
# MonthlyRate               237.0  14559.308017  7208.153264  2326.0  8870.0
# ...

# %%
hr_df = pd.read_csv('Human_Resources.csv')

# %%
index_list = hr_df[hr_df['Attrition'] == 'Yes'].describe().T.index

# %%
df_comparison = pd.DataFrame(columns=['Count_Stayed', 'Count_Left', 'Mean_Stayed', 'Mean_Left'], index=index_list)
df_comparison['Count_Stayed'] = hr_df[hr_df['Attrition'] == 'No'].count()
df_comparison['Count_Left'] = hr_df[hr_df['Attrition'] == 'Yes'].count()
df_comparison['Mean_Stayed'] = hr_df[hr_df['Attrition'] == 'No'].mean()
df_comparison['Mean_Left'] = hr_df[hr_df['Attrition'] == 'Yes'].mean()
df_comparison
# Out:
#                           Count_Stayed  Count_Left   Mean_Stayed     Mean_Left
# Age                               1233         237     37.561233     33.607595
# MonthlyIncome                     1231         236   6837.504468   4771.588983
# DailyRate                         1233         237    812.504461    750.362869
# DistanceFromHome                  1233         237      8.915653     10.632911
# Education                         1233         237      2.927007      2.839662
# EmployeeCount                     1233         237      1.000000      1.000000
# EmployeeNumber                    1232         237   1028.482143   1010.345992
# EnvironmentSatisfaction           1233         237      2.771290      2.464135
# HourlyRate                        1233         237     65.952149     65.573840
# JobInvolvement                    1233         237      2.770479      2.518987
# JobLevel                          1233         237      2.145985      1.637131
# ...

# %% [markdown]
# # Comparision of Left and Stayed
#
# *237 employees have left the company whereas 1233 are still working in the company.
#
# *When examining the age data, it becomes evident that the average age of employees who stayed with the company is higher than that of employees who left.
#
# *Analysis of monthly income data reveals that employees who stayed with the company tend to have higher monthly incomes compared to those who left.
#
# *The data on daily rates suggests that employees who stayed with the company have  higher daily rates than those who left.
#
# *An analysis of the distance from home shows that employees who stayed tend to live closer to the workplace compared to employees who left.
#
# *The data regarding environmental satisfaction levels suggests that employees who stayed tend to have higher environmental satisfaction scores compared to those who left.
#
# *Employees who stayed appear to have higher job involvement levels compared to those who left.
#
# *There is a noticeable difference in job levels between employees who stayed and those who left, with a higher mean job level for those who stayed.
#
# *Job satisfaction levels for those who stayed are generally higher than for those who left.
#
# *Monthly rates for employees who stayed and those who left exhibit a small difference, with slightly lower monthly rates for those who stayed.
#
# *The number of companies worked for employees who stayed is slightly lower compared to those who left.
#
# *Employees who stayed tend to have higher relationship satisfaction scores compared to those who left.
#
# *Employees who stayed appear to have higher stock option levels compared to those who left.
#
# *Total working years for employees who stayed are significantly higher than for those who left.
#
# *Employees who stayed tend to have a slightly higher average of training times last year compared to those who left.

# %% [markdown]
# # CODING TASK #7. PANDAS WITH FUNCTIONS

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# ...

# %%
hr_df = hr_df.dropna()
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
# 5   32         3068.0        No  Travel_Frequently       1005
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
# 5  Research & Development                 2          2  Life Sciences
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# ...

# %%
rate = 1.10
def net_degeri_artir(hr_df):
    yeni_net_deger = hr_df * rate  # %10 artırma işlemi
    return yeni_net_deger

# DataFrame'e işlevi uygulayalım
hr_df['MonthlyIncome'] = hr_df['MonthlyIncome'].apply(net_degeri_artir)
hr_df['DailyRate'] = hr_df['DailyRate'].apply(net_degeri_artir)
hr_df['HourlyRate'] = hr_df['HourlyRate'].apply(net_degeri_artir)
hr_df['MonthlyRate'] = hr_df['MonthlyRate'].apply(net_degeri_artir)

# %%
hr_df.head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         6592.3       Yes      Travel_Rarely     1212.2
# 2   37         2299.0       Yes      Travel_Rarely     1510.3
# 3   33         3199.9        No  Travel_Frequently     1531.2
# 4   27         3814.8        No      Travel_Rarely      650.1
# 5   32         3374.8        No  Travel_Frequently     1105.5
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
# 5  Research & Development                 2          2  Life Sciences
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female       103.4
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #7:**
# - **Define a function that doubles the DailyRate and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total Daily Rate of all employees combined**

# %%
#Define a function that doubles the DailyRate and adds $100
#Apply the function to the DataFrame
def daily_rate_artır(hr_df):
    yeni_net_deger = (hr_df * 2) + 100  # iki katının 100 fazlası
    return yeni_net_deger

# DataFrame'e işlevi uygulayın
hr_df['DailyRate'] = hr_df['DailyRate'].apply(daily_rate_artır)
hr_df.head(5)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         6592.3       Yes      Travel_Rarely     2524.4
# 2   37         2299.0       Yes      Travel_Rarely     3120.6
# 3   33         3199.9        No  Travel_Frequently     3162.4
# 4   27         3814.8        No      Travel_Rarely     1400.2
# 5   32         3374.8        No  Travel_Frequently     2311.0
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
# 5  Research & Development                 2          2  Life Sciences
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female       103.4
# ...

# %%
#Calculate the updated total Daily Rate of all employees combined
hr_df.DailyRate.sum()
# Out:
# 2727964.8000000003

# %% [markdown]
# # CODING TASK #8: HISTOGRAM AND CORRELATION

# %% [markdown]
# - **Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy**
# - **Job level is strongly correlated with total working hours**
# - **Monthly income is strongly correlated with Job level**
# - **Monthly income is strongly correlated with total working hours**
# - **Age is strongly correlated with monthly income**

# %%
columns_to_drop = ["EmployeeCount", "StandardHours"]
hr_df1=hr_df.drop(columns=columns_to_drop, axis=1)
plt.figure(figsize=(15, 12))
sns.heatmap(hr_df1.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, annot_kws={'size': 12})
plt.title('Heat Map')
plt.show()

# %%
#Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy
#Job level is strongly correlated with total working hours
#Monthly income is strongly correlated with Job level
#Monthly income is strongly correlated with total working hours
#Age is strongly correlated with monthly income

strong_corr = hr_df[['MonthlyIncome', 'TotalWorkingYears','JobLevel', 'Age']]

corr_matrix = strong_corr.corr()
# Korelasyon matrisini kullanarak bir heatmap çizelim
plt.figure(figsize=(4, 3))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Strong Correlation Relationship')
plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #8:**
# - **Change the color of the heatmap [External Research is Required]**

# %%
hr_df.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Korelasyon matrisini hesapla
correlation_matrix = hr_df[["Age", "MonthlyIncome", "TotalWorkingYears", "JobLevel"]].corr()

# Korelasyon matrisini bir tablo olarak göster
correlation_table = correlation_matrix.unstack().reset_index()
correlation_table.columns = ['Feature 1', 'Feature 2', 'Correlation']

print(correlation_table)
# Out:
#             Feature 1          Feature 2  Correlation
# 0                 Age                Age     1.000000
# 1                 Age      MonthlyIncome     0.499774
# 2                 Age  TotalWorkingYears     0.682105
# 3                 Age           JobLevel     0.511250
# 4       MonthlyIncome                Age     0.499774
# 5       MonthlyIncome      MonthlyIncome     1.000000
# 6       MonthlyIncome  TotalWorkingYears     0.773105
# 7       MonthlyIncome           JobLevel     0.950317
# 8   TotalWorkingYears                Age     0.682105
# 9   TotalWorkingYears      MonthlyIncome     0.773105
# 10  TotalWorkingYears  TotalWorkingYears     1.000000
# 11  TotalWorkingYears           JobLevel     0.782483
# 12           JobLevel                Age     0.511250
# 13           JobLevel      MonthlyIncome     0.950317
# 14           JobLevel  TotalWorkingYears     0.782483
# 15           JobLevel           JobLevel     1.000000

# %% [markdown]
# ## REASONS
# *The correlation between age and monthly income is 0.50. This indicates a positive correlation, showing that an increase in age is associated with an increase in monthly income.
#
# *The correlation between age and total working years is 0.68. This is a positive correlation, suggesting that as age increases, the total working years also tend to increase.
#
# *The correlation between age and job level is 0.51. This positive correlation implies that as age increases, job level tends to increase as well.
#
#
# *The correlation between monthly income and total working years is 0.77. This is a positive correlation, indicating that an increase in monthly income is associated with an increase in total working years.
#
# *The correlation between monthly income and job level is 0.95. This high positive correlation suggests that an increase in monthly income is strongly associated with an increase in job level.
#
#
# *The correlation between total working years and job level is 0.78. This positive correlation suggests that as total working years increase, job level also tends to increase.

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # FINAL CAPSTONE PROJECT OVERVIEW

# %% [markdown]
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Kyphosis disease Dataset.
# - Kyphosis is an abnormally excessive convex curvature of the spine.
# - Dataset contains 81 rows and 4 columns representing data on children who have had corrective spinal surgery.
#     - INPUTS: 1. Age: in months, 2. Number: the number of vertebrae involved, 3. Start: the number of the first (topmost) vertebra operated on.
#     - OUTPUTS: Kyphosis which represents a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.
# - Using the “kyphosis.csv" included in the course package, write a python script to perform the following tasks:
#     1. Import the “kyphosis.csv" file using Pandas
#     2. Perform basic Exploratory Data Analysis (EDA) on the data
#     3. List the average, minimum and maximum age (in years) considered in this study using 2 methods
#     4. Plot the correlation matrix
#     5. Convert the age column datatype from int64 to float64
#     6. Define a function that converts age from months to years
#     7. Apply the function to the “Age” column and add the results into a new column entitled “Age in Years”
#     8. What are the features of the oldest and youngest child in this study?
#     9. Scale the raw Age column (in months) using both standardization and Normalization. Perform a sanity check.
#     10. Normalization is conducted on the 'Age' column to make feature values range from 0 to 1.

# %%
#Import the “kyphosis.csv" file using Pandas
ks_df= pd.read_csv('kyphosis.csv')
ks_df

# %% [markdown]
# ##Perform basic Exploratory Data Analysis (EDA) on the data

# %%
ks_df.dtypes
# Out:
# Kyphosis    object
# Age          int64
# Number       int64
# Start        int64
# dtype: object

# %%
ks_df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
ks_df.tail()
# Out:
#    Kyphosis  Age  Number  Start
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13

# %%
ks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
ks_df_column = ks_df.isnull().sum()
ks_df_column
# Out:
# Kyphosis    0
# Age         0
# Number      0
# Start       0
# dtype: int64

# %%
#List the average, minimum and maximum age (in years) considered in this study using 2 methods
(ks_df["Age"]/12).describe()[["mean","min","max"]]
# Out:
# mean     6.971193
# min      0.083333
# max     17.166667
# Name: Age, dtype: float64

# %%
ks_df.select_dtypes(include='number').hist(figsize=(8,6))
plt.show()

# %%
#Plot the correlation matrix
plt.figure(figsize=(6, 4))
sns.heatmap(ks_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, annot_kws={'size': 12})  # Yazıları büyütelim
plt.title('Heat Map')
plt.show()

# %%
#Convert the age column datatype from int64 to float64
ks_df["Age"]= ks_df["Age"].astype(float)

# %%
ks_df.dtypes
# Out:
# Kyphosis     object
# Age         float64
# Number        int64
# Start         int64
# dtype: object

# %%
#Define a function that converts age from months to years
#Apply the function to the “Age” column and add the results into a new column entitled “Age in Years”

def convert_year(ks_df):
    Age_year = ks_df / 12
    return Age_year

ks_df["Age(Year)"] = ks_df["Age"].apply(convert_year)
ks_df

# %%
#What are the features of the oldest and youngest child in this study?
min_age = ks_df['Age'].min()
max_age = ks_df['Age'].max()

min_max_df = ks_df[(ks_df['Age'] == min_age) | (ks_df['Age'] == max_age)]
min_max_df
# Out:
#    Kyphosis    Age  Number  Start  Age(Year)
# 4    absent    1.0       4     15   0.083333
# 5    absent    1.0       2     16   0.083333
# 13   absent    1.0       4     12   0.083333
# 15   absent    1.0       3     16   0.083333
# 36   absent    1.0       3      9   0.083333
# 73   absent  206.0       4     10  17.166667

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Standardization (z-score scaling)
scaler_standardization = StandardScaler()
ks_df["Age_Standardized"] = scaler_standardization.fit_transform(ks_df[["Age"]])

# Normalization (min-max scaling)
scaler_normalization = MinMaxScaler()
ks_df["Age_Normalized"] = scaler_normalization.fit_transform(ks_df[["Age"]])

# %%
ks_df

# %% [markdown]
# ## Reasons
# *It is observed that the number of affected vertebrae in patients is concentrated between 2 and 5.
# *Patients are mostly babies a few months old.
# *The first vertebra to be operated on is usually the 15th vertebra from the top.
# *
